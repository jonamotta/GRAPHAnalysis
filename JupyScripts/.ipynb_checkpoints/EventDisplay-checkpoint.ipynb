# %%
import ROOT
import pandas as pd
import numpy as np 
import uproot3 

import os
import sys

import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm
mpl.rcParams['image.cmap'] = 'hot_r'
# Out:
# Welcome to JupyROOT 6.14/04
# /home/llr/cms/motta/.local/lib/python3.7/site-packages/uproot3/__init__.py:138: FutureWarning: Consider switching from 'uproot3' to 'uproot', since the new interface became the default in 2020.
#
#     pip install -U uproot
#
# In Python:
#
#     >>> import uproot
#     >>> with uproot.open(...) as file:
#     ...
#
#   FutureWarning
# /home/llr/cms/motta/.local/lib/python3.7/site-packages/awkward0/__init__.py:23: FutureWarning: Consider switching from 'awkward0' to 'awkward', since the new interface became the default in 2020.
#
#     pip install -U awkward
#
# In Python:
#
#     >>> import awkward as ak
#     >>> new_style_array = ak.from_awkward0(old_style_array)
#     >>> old_style_array = ak.to_awkward0(new_style_array)
#
#   FutureWarning

# %%
branches_tc = ['event', 'tc_layer', 'tc_energy', 'tc_x', 'tc_y', 'tc_z']

branches_cl3d = ['event', 'cl3d_pt', 'cl3d_energy', 'cl3d_eta', 'cl3d_phi']

branches_gentau = ['event', 'gentau_pt', 'gentau_eta', 'gentau_phi', 'gentau_energy', 'gentau_mass', 
                   'gentau_vis_pt', 'gentau_vis_eta', 'gentau_vis_phi', 'gentau_vis_energy', 'gentau_vis_mass', 
                   'gentau_decayMode']

branches_genjet = ['event', 'genjet_pt', 'genjet_eta', 'genjet_phi', 'genjet_energy', 'genjet_mass']

# %% [markdown]
# # **RUN THE FOLLOWING CELL ONLY IF THE hdf5 FILES HAVE NOT BEEN CREATED YET!!**
#
# **IT TAKES ROUGHLY 25min FRO IT TO FINISH**

# %%
# %%time

indir = '/data_CMS_upgrade/motta/HGCAL_SKIMS/SKIM_18Feb2021'

dfTau = uproot3.open(indir+'/SKIM_RelValTenTau_PU200/mergedOutput.root')['SkimmedTree'].pandas.df(branches_tc, flatten=False)
#dfHH = uproot3.open(indir+'/SKIM_GluGluHHTo2b2Tau_PU200/mergedOutput.root')['SkimmedTree'].pandas.df(branches_tc, flatten=False)
#dfQCD = uproot3.open(indir+'/SKIM_QCD_PU200/mergedOutput.root')['SkimmedTree'].pandas.df(branches_tc, flatten=False)
#dfNu = uproot3.open(indir+'/SKIM_RelValNu_PU200/mergedOutput.root')['SkimmedTree'].pandas.df(branches_tc, flatten=False)

# outdir = '../L1GNN/hdf5dataframes/visualization'
# os.system('mkdir -p '+outdir)

# store_tau = pd.HDFStore(outdir+'/RelValTenTau_PU200_th_visualization.hdf5', mode='w')
# store_tau.append('th', dfTau)
# store_tau.close()

# store_hh = pd.HDFStore(outdir+'/GluGluHHTo2b2Tau_PU200_th_visualization.hdf5', mode='w')
# store_hh.append('th', dfHH)
# store_hh.close()

# store_qcd = pd.HDFStore(outdir+'QCD_PU200_th_visualization.hdf5', mode='w')
# store_qcd.append('th', dfQCD)
# store_qcd.close()

# store_nu = pd.HDFStore(outdir+'RelValNu_PU200_th_visualization.hdf5', mode='w')
# store_nu.append('th', dfNu)
# store_nu.close()
# Out:
# CPU times: user 29.1 s, sys: 7.76 s, total: 36.9 s
# Wall time: 45.2 s

# %% [markdown]
# # **RUN FROM HERE ON IF THE hdf5 FILES HAVE ALREADY BEEN CREATED!!**

# %%
indir = '../L1GNN/hdf5dataframes/visualization'

store_tau = pd.HDFStore(indir+'/RelValTenTau_PU200_th_visualization.hdf5', mode='r')
dfTau = store_tau['th']
store_tau.close()

store_hh= pd.HDFStore(indir+'/RelValTenTau_PU200_th_visualization.hdf5', mode='r')
dfHH = store_hh['th']
store_hh.close()

store_qcd = pd.HDFStore(indir+'/RelValTenTau_PU200_th_visualization.hdf5', mode='r')
dfQCD = store_qcd['th']
store_qcd.close()

store_nu = pd.HDFStore(indir+'/RelValTenTau_PU200_th_visualization.hdf5', mode='r')
dfNu = store_nu['th']
store_nu.close()

# %%
dfTau = dfTau.query("(gentau_vis_eta>1.6 and gentau_vis_eta<2.9) or (gentau_vis_eta<-1.6 and gentau_vis_eta>-2.9)")
dfHH = dfHH.query("(gentau_vis_eta>1.6 and gentau_vis_eta<2.9) or (gentau_vis_eta<-1.6 and gentau_vis_eta>-2.9)")
dfQCD = dfQCD.query("(genjet_eta>1.6 and genjet_eta<2.9) or (genjet_eta<-1.6 and genjet_eta>-2.9)")
dfNu = dfNu.query("(cl3d_eta>1.6 and cl3d_eta<2.9) or (cl3d_eta<-1.6 and cl3d_eta>-2.9)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/exp_soft/llr/python/3.7.0/el7/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# /opt/exp_soft/llr/python/3.7.0/el7/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# /opt/exp_soft/llr/python/3.7.0/el7/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'gentau_vis_eta'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
events = len(dfTau.event.unique())

# %%
events
# Out:
# 9000

# %%
dfTau.head()
# Out:
#        event                                           tc_layer  \
# entry
# 0       7102  [43, 37, 41, 40, 44, 40, 43, 37, 37, 37, 50, 4...
# 1       7108  [50, 45, 43, 43, 45, 44, 37, 37, 37, 39, 38, 3...
# 2       7103  [37, 40, 44, 39, 38, 46, 40, 37, 37, 43, 40, 3...
# 3       7106  [50, 37, 38, 48, 37, 37, 39, 41, 37, 37, 47, 4...
# 4       7107  [44, 44, 41, 40, 37, 39, 40, 43, 40, 40, 38, 3...
#
#                                                tc_energy  \
# entry
# 0      [0.31360757, 0.30701286, 0.39200947, 0.5392999...
# 1      [2.0751405, 0.62721515, 0.39200947, 1.0453585,...
# 2      [1.719272, 0.9956306, 1.463502, 1.719272, 0.85...
# 3      [0.8300562, 0.46051928, 0.30701286, 1.4525983,...
# 4      [1.2544303, 0.52267927, 0.8362869, 0.31113455,...
#
#                                                     tc_x  \
# entry
# 0      [49.96703, 88.43581, 92.06937, -118.599236, 13...
# 1      [-133.02232, 113.18666, 80.77908, 87.890884, 8...
# ...

# %%
uniques = 0

for event in range(events):
    df_single = df.loc[event]
    esum_tot = np.sum(df_single.rechit_energy)
    esum = 0.0
    
    for layer, energy in zip(df_single.rechit_layer, df_single.rechit_energy):
        if layer > 28:
            esum += energy
            
    fh_ratio = esum/esum_tot
    if fh_ratio > 0.1:
        uniques += 0
        print('More than 0.1:', event)
        if fh_ratio > 0.2:
            print('More than 0.2:', event)
            if fh_ratio > 0.3:
                print('More than 0.3:', event)
# Out:
# More than 0.1: 305
# More than 0.2: 305
# More than 0.1: 2049
# More than 0.1: 2091
# More than 0.2: 2091
# More than 0.3: 2091
# More than 0.1: 2557
# More than 0.1: 3834
# More than 0.2: 3834
# More than 0.1: 3859
# More than 0.1: 4170
# More than 0.2: 4170
# More than 0.3: 4170
# More than 0.1: 5953
# More than 0.2: 5953
# More than 0.3: 5953
# More than 0.1: 5983
# More than 0.2: 5983
# More than 0.1: 8817
# More than 0.1: 9066
# More than 0.2: 9066
# More than 0.3: 9066
# More than 0.1: 9911
# More than 0.1: 10053
# More than 0.2: 10053
# More than 0.3: 10053
# More than 0.1: 10127
# More than 0.2: 10127
# More than 0.3: 10127
# More than 0.1: 10367
# More than 0.2: 10367
# More than 0.3: 10367
# More than 0.1: 10373
# More than 0.2: 10373
# More than 0.1: 10417
# More than 0.2: 10417
# More than 0.3: 10417

# %%
# esum_tot = [np.sum(esum) for esum in df.rechit_energy]

# %%
# fig = plt.figure(figsize = (10, 8))

# t = plt.hist(esum_tot, 100, histtype = 'step')

# %%
fig = plt.figure(figsize = (15, 15))
ax1 = fig.add_subplot(111, projection='3d')
cmap = 'viridis'

event = 7107
df_y_xyz = dfTau.loc[event]
x = df_y_xyz.tc_x
y = df_y_xyz.tc_y
z = df_y_xyz.tc_z

c = df_y_xyz.tc_z
s = np.sqrt(df_y_xyz.tc_energy)*10

ax1.scatter(x, z, y, c = c, s = s, marker = 'o', cmap = cmap)

# %%
fig = plt.figure(figsize = (20,12))
ax1 = fig.add_subplot(221, projection='3d')
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

event = 7107
df_y_xyz = dfTau.loc[event]


cmap = 'viridis'

x = df_y_xyz.tc_x
y = df_y_xyz.tc_y
z = df_y_xyz.tc_z
z = df_y_xyz.tc_layer

c = df_y_xyz.tc_layer
s = np.sqrt(df_y_xyz.tc_energy)*10

m_style = 'o'
ax1.scatter(x, z, y, c = c, s = s, marker = m_style, cmap = cmap)
ax2.scatter(z, x, c = c, s = s, marker = m_style, cmap = cmap)
ax3.scatter(z, y, c = c, s = s, marker = m_style, cmap = cmap)
m_style = 'H'
ax4.scatter(x, y, c = c, s = s, marker = m_style, cmap = cmap)

ax1.set_xlabel('x'); ax1.set_ylabel('z'); ax1.set_zlabel('y')
ax2.set_xlabel('z'); ax2.set_ylabel('x')
ax3.set_xlabel('z'); ax3.set_ylabel('y')
ax4.set_xlabel('x'); ax4.set_ylabel('y')

ax4.set_ylim(-20,20)
ax4.set_xlim(-30,30)

# ax1.set_xlim(-40,40)
# ax1.set_zlim(-40,40)
# ax1.set_ylim(0,150)

#fig.suptitle('Event %i' % event)#, fontsize=16)
ax1.set_title('Event %i' % event)
# Out:
# Text(0.5, 0.92, 'Event 7107')
