# %%
import pickle
import xgboost as xgb
import pandas as pd
import numpy as np

def save_obj(obj,dest):
    with open(dest,'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(source):
    with open(source,'rb') as f:
        return pickle.load(f)

# %%
cl3d_showerlength = [36, 39, 40, 35, 34, 33, 37, 42, 42, 29, 30, 36, 42, 30, 35, 38, 29, 35, 31, 40, 29, 32, 32, 37, 39, 30, 33, 32, 21, 27, 29, 31, 25, 31, 19, 17, 15, 28, 33, 27, 47, 33, 37, 46, 41, 33, 31, 35, 30, 50, 29, 35, 27, 28, 25, 37, 30, 29, 34, 41, 21, 40, 46, 32, 25, 29, 31, 5, 9, 25]
cl3d_coreshowerlength = [15, 10, 10, 13, 9, 14, 6, 13, 7, 9, 9, 7, 10, 6, 5, 9, 9, 7, 8, 8, 6, 9, 8, 8, 9, 9, 6, 4, 8, 8, 7, 8, 6, 2, 3, 9, 2, 3, 5, 10, 9, 9, 9, 10, 14, 8, 6, 13, 11, 9, 9, 13, 11, 4, 3, 12, 10, 12, 2, 5, 9, 7, 8, 7, 8, 3, 2, 1, 3, 2]
cl3d_abseta = [2.8745, 2.88256, 2.86664, 2.89197, 2.72434, 2.73504, 2.75481, 2.68101, 2.66192, 2.63181, 2.64703, 2.62997, 2.65954, 2.6181, 2.5422, 2.56137, 2.54953, 2.57309, 2.50743, 2.5057, 2.52051, 2.52633, 2.4293, 2.42664, 2.4182, 2.39965, 2.35732, 2.34091, 2.3147, 2.31275, 2.28152, 2.24629, 2.2117, 2.12399, 2.05333, 1.8717, 1.82165, 1.6596, 2.88612, 2.88321, 2.75897, 2.71611, 2.70154, 2.6351, 2.64355, 2.67783, 2.66998, 2.58127, 2.55352, 2.59189, 2.56282, 2.51148, 2.52532, 2.3997, 2.4195, 2.43531, 2.40516, 2.3719, 2.30698, 2.30281, 2.30739, 2.30509, 2.29121, 2.14166, 2.06986, 2.0375, 1.9779, 1.85, 1.76858, 1.61684]
cl3d_spptot = [0.0507148, 0.0560651, 0.0335778, 0.0615488, 0.0571281, 0.0423954, 0.0526622, 0.0513792, 0.044169, 0.046669, 0.0485373, 0.0439432, 0.0418449, 0.0412898, 0.0447453, 0.0419937, 0.0334273, 0.0420075, 0.0428482, 0.0328301, 0.0358253, 0.0350243, 0.0391379, 0.0292497, 0.0521896, 0.0234807, 0.0196477, 0.0367944, 0.0248518, 0.0279796, 0.0225257, 0.030757, 0.0198919, 0.0109972, 0.0120821, 0.0215738, 0.00401706, 0.00320102, 0.0669115, 0.0629402, 0.0328888, 0.0417385, 0.0324387, 0.0383691, 0.0463479, 0.0583387, 0.0447267, 0.0403691, 0.0426642, 0.0453902, 0.0345599, 0.047415, 0.0471672, 0.0324563, 0.0302662, 0.027225, 0.0284459, 0.0385829, 0.0303255, 0.0232581, 0.024943, 0.0342036, 0.0425497, 0.0175971, 0.0250334, 0.0226588, 0.0166786, 0.00840113, 0.00449695, 0.00657583]
cl3d_srrmean = [0.00345892, 0.00411237, 0.00350957, 0.00409898, 0.00382347, 0.00295203, 0.0044008, 0.00364478, 0.00330204, 0.0034307, 0.00222936, 0.00393587, 0.00484258, 0.00354911, 0.00279548, 0.00377017, 0.00422407, 0.00418136, 0.00445737, 0.00408817, 0.00384533, 0.00374325, 0.00380875, 0.00351983, 0.00295819, 0.00298812, 0.00216117, 0.00311949, 0.00274665, 0.00417613, 0.00337179, 0.0040137, 0.00297939, 0.000631064, 0.000904475, 0.00370579, 0.00116965, 0.000182741, 0.00290323, 0.00494255, 0.00293023, 0.00473473, 0.00185686, 0.00415876, 0.00302697, 0.00469527, 0.00210816, 0.00384406, 0.0038524, 0.00400991, 0.00269227, 0.00311919, 0.00409912, 0.00414462, 0.00264463, 0.00338798, 0.00306862, 0.00384011, 0.000930512, 0.00259441, 0.00275698, 0.00408488, 0.000707584, 0.00240011, 0.00259081, 0.000947295, 0.0022118, 0, 0.00244491, 0.00103596]
cl3d_meanz = [353.433, 352.166, 351.025, 338.287, 336.707, 342.583, 345.876, 338.568, 364.488, 342.452, 340.689, 344.031, 344.735, 345.175, 351.872, 342.418, 335.01, 338.58, 337.631, 350.078, 337.768, 337.283, 339.598, 350.685, 342.497, 353.366, 336.253, 337.511, 332.004, 333.614, 339.715, 339.783, 330.752, 383.223, 341.934, 332.152, 347.329, 371.682, 344.674, 332.14, 402.36, 337.351, 373.887, 347.432, 352.756, 333.718, 342.755, 342.173, 336.226, 369.574, 336.392, 352.538, 333.815, 343.102, 347.92, 354.024, 345.011, 341.24, 362.57, 351.978, 337.245, 364.898, 390.632, 351.11, 333.213, 338.638, 354.095, 340.207, 330.957, 378.024]
cl3d_c3 = [0.982124, 0.970802, 0.978909, 0.977604, 0.935745, 0.87822, 0.83873, 0.93222, 0.73278, 0.95591, 0.949974, 0.89447, 0.953331, 0.870132, 0.880836, 0.959351, 0.877228, 0.859756, 0.869843, 0.872185, 0.83847, 0.886604, 0.843292, 0.888618, 0.93924, 0.862312, 0.799026, 0.798866, 0.862373, 0.767639, 0.831909, 0.833427, 0.746002, 0.705856, 0.747231, 0.824501, 0.650391, 0.536301, 0.949951, 0.972092, 0.805656, 0.893837, 0.839836, 0.964798, 0.960571, 0.839638, 0.930046, 0.965141, 0.95015, 0.907288, 0.864929, 0.945602, 0.96328, 0.871902, 0.863594, 0.944191, 0.946297, 0.908592, 0.778732, 0.843658, 0.890182, 0.752251, 0.8088, 0.801514, 0.744186, 0.757126, 0.727112, 0.712128, 0.65274, 0.500504]
cl3d_hoe = [0.255575, 0.612912, 0.474638, 0.24627, 0.307104, 0.381671, 0.350237, 0.177648, 2.52743, 0.294224, 0.880569, 0.360871, 0.239768, 0.45323, 0.542486, 0.17811, 0.978522, 0.13134, 0.334098, 0.457082, 0.403443, 0.595039, 0.881264, 0.37309, 0.0769846, 1.30489, 0.474252, 0.485666, 0.0649158, 0, 0.214818, 0.222414, 0.499836, 5.20363, 0.0170355, 0.0430874, 0, 20.3416, 1.20553, 0.0364802, 1.39765, 0.492395, 2.42748, 0.421697, 0.384799, 0.547126, 0.10849, 0.212652, 0.567526, 0.787704, 0.319949, 0.848676, 0.2609, 1.45461, 0.541629, 0.592227, 0.323533, 0.651254, 1.97474, 0.631804, 0.297832, 0.991376, 0.818145, 0.393728, 0.946651, 0.127358, 0.301766, 0.197483, 0.0259555, 25.4884]
cl3d_srrtot = [0.00626188, 0.00834906, 0.00812192, 0.0060249, 0.00576349, 0.00770988, 0.00665723, 0.00580734, 0.00505007, 0.00496011, 0.00616187, 0.0054452, 0.00756864, 0.00529501, 0.00602463, 0.00704566, 0.0047125, 0.00593585, 0.00626543, 0.00636273, 0.00513074, 0.00429852, 0.00659368, 0.00579675, 0.00519371, 0.00416406, 0.00445264, 0.00627716, 0.00566351, 0.00481013, 0.0051661, 0.00572606, 0.00402591, 0.00204462, 0.00218529, 0.00519117, 0.00344127, 0.00192776, 0.00726904, 0.00609092, 0.00817967, 0.00760018, 0.00440027, 0.00666153, 0.00549109, 0.00575024, 0.00786155, 0.00509576, 0.00730374, 0.00806112, 0.00450399, 0.00606282, 0.005996, 0.00550469, 0.00442642, 0.00632428, 0.00410522, 0.00767106, 0.00436574, 0.0043084, 0.00420104, 0.00678688, 0.0073347, 0.00493943, 0.0047147, 0.00341285, 0.00426048, 0.000551694, 0.00339521, 0.00148211]
cl3d_pt = [4.55935, 7.95629, 6.00373, 7.15262, 8.9149, 13.0615, 10.4818, 10.4731, 14.4535, 5.72459, 6.55774, 5.99213, 7.40486, 7.09691, 5.53803, 4.39135, 10.92, 7.04267, 6.51897, 6.37047, 7.38275, 9.98152, 6.87336, 4.42102, 4.53741, 9.90541, 7.13117, 6.9196, 4.35613, 9.17646, 4.54491, 4.95041, 7.79035, 8.67302, 5.62269, 5.28073, 6.82179, 15.7761, 5.87611, 7.73322, 18.2322, 12.004, 15.3401, 5.62043, 5.15416, 10.3625, 4.42181, 5.42213, 6.34744, 9.39905, 11.9038, 6.90743, 4.37961, 4.10532, 4.79109, 5.7654, 4.7854, 8.06968, 7.4441, 4.23501, 6.83075, 8.74045, 6.79537, 4.16948, 7.16585, 4.92494, 5.63353, 4.70821, 5.01265, 19.1224, ]

# %%
C1score = [8.00301, 7.89601, 8.10735, 7.77103, 9.99698, 9.85488, 9.59243, 10.5723, 10.8259, 11.2256, 11.0236, 11.2501, 10.8575, 11.4078, 12.4156, 12.1611, 12.3184, 12.0055, 12.8773, 12.9003, 12.7037, 12.6264, 13.9148, 13.9502, 14.0622, 14.3085, 14.8706, 15.0885, 15.4366, 15.4625, 15.8773, 16.345, 16.8043, 17.9691, 18.9074, 21.3193, 21.9839, 24.1357, 7.84872, 7.88732, 9.53708, 10.1063, 10.2998, 11.182, 11.0697, 10.6145, 10.7189, 11.8969, 12.2654, 11.7558, 12.1418, 12.8236, 12.6398, 14.3079, 14.045, 13.835, 14.2353, 14.6771, 15.5392, 15.5945, 15.5337, 15.5642, 15.7486, 17.7345, 18.6879, 19.1175, 19.909, 21.6074, 22.6886, 24.7036]
C2score_skl = [4.96765, 4.73893, 4.73893, 4.58619, 5.02279, 5.07832, 6.43408, 4.58619, 6.42799, 5.02279, 5.02279, 6.42799, 4.73893, 6.43408, 6.43408, 5.02279, 5.02279, 6.42799, 6.14305, 6.14305, 6.43408, 5.02279, 6.14305, 6.14305, 5.02279, 5.02279, 6.43408, 6.43408, 6.14305, 6.14305, 6.42799, 6.14305, 6.43408, 6.43408, 6.43408, 5.02279, 6.63854, 9.45666, 6.43408, 4.73893, 5.02279, 5.02279, 5.02279, 4.73893, 5.07832, 6.14305, 6.43408, 4.58619, 4.73893, 5.02279, 5.02279, 4.58619, 4.73893, 6.43408, 6.43408, 4.65015, 4.73893, 4.65015, 6.43408, 6.43408, 5.02279, 6.42799, 6.14305, 6.42799, 6.14305, 6.43408, 6.43408, 6.43408, 6.87094, 6.43408]
C3score_skl = [0.982124, 0.970802, 0.978909, 0.977604, 0.935745, 0.87822, 0.83873, 0.93222, 0.73278, 0.95591, 0.949974, 0.89447, 0.953331, 0.870132, 0.880836, 0.959351, 0.877228, 0.859756, 0.869843, 0.872185, 0.83847, 0.886604, 0.843292, 0.888618, 0.93924, 0.862312, 0.799026, 0.798866, 0.862373, 0.767639, 0.831909, 0.833427, 0.746002, 0.705856, 0.747231, 0.824501, 0.650391, 0.536301, 0.949951, 0.972092, 0.805656, 0.893837, 0.839836, 0.964798, 0.960571, 0.839638, 0.930046, 0.965141, 0.95015, 0.907288, 0.864929, 0.945602, 0.96328, 0.871902, 0.863594, 0.944191, 0.946297, 0.908592, 0.778732, 0.843658, 0.890182, 0.752251, 0.8088, 0.801514, 0.744186, 0.757126, 0.727112, 0.712128, 0.65274, 0.500504]

C2score_xgb = [1.43485, 1.40086, 1.74334, 1.24878, 1.34853, 1.38781, 1.43027, 1.25848, 1.46018, 1.37265, 1.46903, 1.47481, 1.36145, 1.41842, 1.45415, 1.40638, 1.33043, 1.45417, 1.40044, 1.43267, 1.37521, 1.32976, 1.36513, 1.38202, 1.53592, 1.31096, 1.37882, 1.39506, 1.37625, 1.34928, 1.3508, 1.34757, 1.37205, 1.23202, 1.26286, 1.32588, 1.27501, 1.22334, 1.61497, 1.34376, 1.49067, 1.39361, 1.38408, 1.34263, 1.36383, 1.35491, 1.49633, 1.30441, 1.268, 1.4856, 1.31902, 1.30196, 1.25524, 1.36795, 1.40506, 1.35511, 1.29309, 1.30065, 1.3489, 1.44577, 1.26283, 1.4516, 1.46971, 1.33554, 1.3379, 1.34654, 1.33399, 1.28723, 1.36047, 1.26212]
C3score_xgb = [2.16856, 1.63019, 1.44533, 2.06596, 1.39066, 1.15307, 1.24426, 1.33867, 1.06584, 1.54027, 1.37269, 1.39488, 1.4287, 1.35063, 1.35784, 1.53933, 1.17541, 1.28357, 1.30675, 1.28734, 1.28677, 1.19962, 1.25659, 1.39718, 1.24951, 1.1545, 1.19152, 1.18123, 1.30333, 1.12208, 1.28834, 1.24475, 1.11266, 1.13051, 1.17375, 1.08762, 1.06811, 0.997189, 1.634, 1.75256, 1.02636, 1.1782, 1.08443, 1.59866, 1.63758, 1.25497, 1.59041, 1.59595, 1.51473, 1.16222, 1.15516, 1.38028, 1.7126, 1.40895, 1.33964, 1.33497, 1.44567, 1.21441, 1.17314, 1.2458, 1.26178, 1.08745, 1.12424, 1.22536, 1.09815, 1.14006, 1.10681, 1.11032, 1.05719, 0.98761]

PUscore_skl = [-0.727026, -0.912718, -0.883026, -0.800659, -0.74844, -0.93515, -0.994197, -0.801477, -0.961607, -0.660686, -0.986005, -0.961182, -0.920958, -0.990885, -0.990003, -0.895116, -0.765312, -0.977798, -0.959531, -0.950717, -0.989864, -0.444686, -0.949942, -0.929107, -0.740196, -0.354021, -0.999216, -0.996843, -0.928989, -0.95856, -0.969771, -0.939413, -0.989778, -0.999011, -0.999749, -0.866286, -0.999749, -0.999558, -0.994433, -0.716344, -0.867543, -0.953155, -0.955034, -0.891488, -0.391475, -0.971001, -0.998414, -0.255532, -0.893373, -0.834921, -0.79647, -0.765971, -0.749993, -0.995849, -0.995434, -0.738391, -0.332836, -0.838328, -0.999405, -0.989659, -0.681822, -0.991442, -0.944363, -0.990896, -0.940839, -0.999821, -0.999644, -0.999749, -0.998767, -0.999727]
PUscore_xgb = [-0.727026, -0.912718, -0.883026, -0.800659, -0.74844, -0.93515, -0.994197, -0.801477, -0.961607, -0.660686, -0.986005, -0.961182, -0.920958, -0.990885, -0.990003, -0.895116, -0.765312, -0.977798, -0.959531, -0.950717, -0.989864, -0.444686, -0.949942, -0.929107, -0.740196, -0.354021, -0.999216, -0.996843, -0.928989, -0.95856, -0.969771, -0.939413, -0.989778, -0.999011, -0.999749, -0.866286, -0.999749, -0.999558, -0.994433, -0.716344, -0.867543, -0.953155, -0.955034, -0.891488, -0.391475, -0.971001, -0.998414, -0.255532, -0.893373, -0.834921, -0.79647, -0.765971, -0.749993, -0.995849, -0.995434, -0.738391, -0.332836, -0.838328, -0.999405, -0.989659, -0.681822, -0.991442, -0.944363, -0.990896, -0.940839, -0.999821, -0.999644, -0.999749, -0.998767, -0.999727]

# %%
PUfeatures = ["cl3d_c3", "cl3d_coreshowerlength", "cl3d_srrtot", "cl3d_srrmean", "cl3d_hoe", "cl3d_meanz"]

C2features = ["cl3d_showerlength", "cl3d_coreshowerlength", "cl3d_abseta", "cl3d_spptot", "cl3d_srrmean", "cl3d_meanz"]

# %%
df = pd.DataFrame()

# %%
df['cl3d_showerlength'] = cl3d_showerlength
df['cl3d_coreshowerlength'] = cl3d_coreshowerlength
df['cl3d_abseta'] = cl3d_abseta
df['cl3d_spptot'] = cl3d_spptot
df['cl3d_srrmean'] = cl3d_srrmean
df['cl3d_meanz'] = cl3d_meanz
df['cl3d_c3'] = cl3d_c3
df['cl3d_hoe'] = cl3d_hoe
df['cl3d_srrtot'] = cl3d_srrtot
df['cl3d_pt'] = cl3d_pt

df['TMVA_C1_score'] = C1score
df['TMVA_C2_score_GradSkl'] = C2score_skl
df['TMVA_C3_score_GradSkl'] = C3score_skl
df['TMVA_PU_score_GradSkl'] = PUscore_skl

df['TMVA_C2_score_GradXgb'] = C2score_xgb
df['TMVA_C3_score_GradXgb'] = C3score_xgb
df['TMVA_PU_score_GradXgb'] = PUscore_xgb

# %%
PUmodel = load_obj('/home/llr/cms/motta/HGCAL/CMSSW_11_1_0/src/GRAPHAnalysis/L1BDT/pklModels/PUrejection_skimPUnoPt/model_PUrejection_th_PU200.pkl')

C1model = load_obj('/home/llr/cms/motta/HGCAL/CMSSW_11_1_0/src/GRAPHAnalysis/L1BDT/pklModels/calibration_C1skimC2C3/model_c1_th_PU200.pkl')
C2model_skl = load_obj('/home/llr/cms/motta/HGCAL/CMSSW_11_1_0/src/GRAPHAnalysis/L1BDT/pklModels/calibration_C1skimC2C3/model_c2_th_PU200.pkl')
C3model_skl = load_obj('/home/llr/cms/motta/HGCAL/CMSSW_11_1_0/src/GRAPHAnalysis/L1BDT/pklModels/calibration_C1skimC2C3/model_c3_th_PU200.pkl')

C2model_xgb = load_obj('/home/llr/cms/motta/HGCAL/CMSSW_11_1_0/src/GRAPHAnalysis/L1BDT/pklModels/calibration_C1skimC2C3_xgb/model_c2_th_PU200.pkl')
C3model_xgb = load_obj('/home/llr/cms/motta/HGCAL/CMSSW_11_1_0/src/GRAPHAnalysis/L1BDT/pklModels/calibration_C1skimC2C3_xgb/model_c3_th_PU200.pkl')

# %%
PUfull = xgb.DMatrix(data=df[PUfeatures], feature_names=PUfeatures)

# %%
df['XGB_PU_score'] = PUmodel.predict(PUfull)

df['C1_score'] = C1model.predict(df[['cl3d_abseta']])
df['SKL_C2_score'] = C2model_skl.predict(df[C2features])
df['XGB_C2_score'] = C2model_xgb.predict(df[C2features])

logpt1 = np.log(abs((df['cl3d_pt']+df['C1_score'])*df['SKL_C2_score']))
logpt2 = logpt1**2
logpt3 = logpt1**3
logpt4 = logpt1**4
df['SKL_C3_score'] = C3model_skl.predict(np.vstack([logpt1, logpt2, logpt3, logpt4]).T)

logpt1 = np.log(abs((df['cl3d_pt']+df['C1_score'])*df['XGB_C2_score']))
logpt2 = logpt1**2
logpt3 = logpt1**3
logpt4 = logpt1**4
df['XGB_C3_score'] = C3model_xgb.predict(np.vstack([logpt1, logpt2, logpt3, logpt4]).T)

# %%
df['test_skl'] = df['TMVA_C2_score_GradSkl'] / df['SKL_C2_score']
df['test_xgb'] = df['TMVA_C2_score_GradXgb'] / df['XGB_C2_score']

# %%
df[['SKL_C2_score', 'TMVA_C2_score_GradSkl', 'test_skl', 'XGB_C2_score', 'TMVA_C2_score_GradXgb', 'test_xgb']]
# Out:
#     SKL_C2_score  TMVA_C2_score_GradSkl  test_skl  XGB_C2_score  \
# 0       1.482263                4.96765  3.351395      0.934846
# 1       1.507399                4.73893  3.143780      0.900859
# 2       1.507399                4.73893  3.143780      1.243343
# 3       1.401549                4.58619  3.272230      0.748780
# 4       1.535785                5.02279  3.270504      0.848534
# 5       1.466525                5.07832  3.462825      0.887810
# 6       1.614503                6.43408  3.985178      0.930266
# 7       1.401549                4.58619  3.272230      0.758482
# 8       1.614503                6.42799  3.981406      0.960177
# 9       1.535785                5.02279  3.270504      0.872650
# 10      1.535785                5.02279  3.270504      0.969028
# 11      1.614503                6.42799  3.981406      0.974809
# 12      1.507399                4.73893  3.143780      0.861448
# 13      1.614503                6.43408  3.985178      0.918425
# ...

# %%
df[['XGB_PU_score', 'TMVA_PU_score_GradSkl', 'TMVA_PU_score_GradXgb']]
# Out:
#     XGB_PU_score  TMVA_PU_score_GradSkl  TMVA_PU_score_GradXgb
# 0       0.179999              -0.727026              -0.727026
# 1       0.100990              -0.912718              -0.912718
# 2       0.121952              -0.883026              -0.883026
# 3       0.221008              -0.800659              -0.800659
# 4       0.192811              -0.748440              -0.748440
# 5       0.109337              -0.935150              -0.935150
# 6       0.026003              -0.994197              -0.994197
# 7       0.256613              -0.801477              -0.801477
# 8       0.103003              -0.961607              -0.961607
# 9       0.311469              -0.660686              -0.660686
# 10      0.075296              -0.986005              -0.986005
# 11      0.119099              -0.961182              -0.961182
# 12      0.104830              -0.920958              -0.920958
# 13      0.062771              -0.990885              -0.990885
# ...

# %%
np.array(df['SKL_C3_score'])
# Out:
# array([2.04999764, 1.48677585, 1.71112824, 1.74881563, 1.2311086 ,
#        1.11582118, 1.13954788, 1.21624592, 1.03184664, 1.35796908,
#        1.31122628, 1.27566809, 1.28832607, 1.20444727, 1.23309654,
#        1.39089471, 1.08270905, 1.1794054 , 1.17658761, 1.18194946,
#        1.13912456, 1.09695714, 1.12593048, 1.22496485, 1.24793061,
#        1.06402776, 1.08503548, 1.08489138, 1.16057912, 1.04423075,
#        1.1279395 , 1.11093266, 1.04002995, 1.0188321 , 1.04086866,
#        1.03158518, 1.00481335, 0.98094975, 1.62526872, 1.51186296,
#        1.02073282, 1.10959753, 1.04273077, 1.39616002, 1.49402997,
#        1.12015344, 1.44982637, 1.46104104, 1.26701499, 1.13785136,
#        1.06698667, 1.28312693, 1.37794487, 1.20896359, 1.1888217 ,
#        1.29271319, 1.24408482, 1.15256683, 1.06494307, 1.14825486,
#        1.1029782 , 1.04388765, 1.08029244, 1.08728698, 1.0297083 ,
#        1.04759338, 1.02901678, 1.02160028, 1.01112386, 0.97528246])
